# %%
# %%capture
# Clone the repository (can take 3min)
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents

# %%
# %%capture
# Go inside the repository and install the package (can take 3min)
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %%
# !mkdir ./trained-envs-executables
# !mkdir ./trained-envs-executables/linux

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF" -O ./trained-envs-executables/linux/Huggy.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-12-17 14:00:59--  https://docs.google.com/uc?export=download&confirm=t&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF
# Resolving docs.google.com (docs.google.com)... 74.125.24.113, 74.125.24.100, 74.125.24.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.24.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/seqs1covatv9a8lvb9dak80615fuai50/1702821600000/15803371278684422230/*/1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF?e=download&uuid=7d0c3442-7007-46a4-b5de-7d7bd5eebb4f [following]
# Warning: wildcards not supported in HTTP.
# --2023-12-17 14:00:59--  https://doc-0k-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/seqs1covatv9a8lvb9dak80615fuai50/1702821600000/15803371278684422230/*/1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF?e=download&uuid=7d0c3442-7007-46a4-b5de-7d7bd5eebb4f
# Resolving doc-0k-28-docs.googleusercontent.com (doc-0k-28-docs.googleusercontent.com)... 74.125.130.132, 2404:6800:4003:c01::84
# Connecting to doc-0k-28-docs.googleusercontent.com (doc-0k-28-docs.googleusercontent.com)|74.125.130.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39214997 (37M) [application/x-zip-compressed]
# Saving to: ‘./trained-envs-executables/linux/Huggy.zip’
#
# ./trained-envs-exec 100%[===================>]  37.40M   136MB/s    in 0.3s
#
# 2023-12-17 14:01:00 (136 MB/s) - ‘./trained-envs-executables/linux/Huggy.zip’ saved [39214997/39214997]

# %%
# %%capture
# !unzip -d ./trained-envs-executables/linux/ ./trained-envs-executables/linux/Huggy.zip

# %%
# !chmod -R 755 ./trained-envs-executables/linux/Huggy

# %%
# !mlagents-learn ./config/ppo/Huggy.yaml --env=./trained-envs-executables/linux/Huggy/Huggy --run-id="Huggy" --no-graphics
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0.dev0,
#   ml-agents-envs: 1.1.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.1.2+cu121
# [INFO] Connected to Unity environment with package version 2.2.1-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: Huggy?team=0
# [INFO] Hyperparameters for behavior name Huggy:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	3000
# 	  buffer_size:	20500
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	200000
# 	network_settings:
# 	  normalize:	True
# 	  hidden_units:	512
# 	  num_layers:	3
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.995
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	init_path:	None
# 	keep_checkpoints:	15
# 	even_checkpoints:	False
# 	max_steps:	2000000
# 	time_horizon:	1000
# 	summary_freq:	50000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Huggy. Step: 50000. Time Elapsed: 70.254 s. Mean Reward: 1.771. Std of Reward: 0.849. Training.
# [INFO] Huggy. Step: 100000. Time Elapsed: 130.933 s. Mean Reward: 2.487. Std of Reward: 1.065. Training.
# [INFO] Huggy. Step: 150000. Time Elapsed: 194.847 s. Mean Reward: 3.032. Std of Reward: 1.212. Training.
# [INFO] Huggy. Step: 200000. Time Elapsed: 256.287 s. Mean Reward: 3.413. Std of Reward: 1.403. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-199973.onnx
# [INFO] Huggy. Step: 250000. Time Elapsed: 320.803 s. Mean Reward: 3.598. Std of Reward: 1.618. Training.
# [INFO] Huggy. Step: 300000. Time Elapsed: 381.977 s. Mean Reward: 3.631. Std of Reward: 1.511. Training.
# [INFO] Huggy. Step: 350000. Time Elapsed: 448.807 s. Mean Reward: 3.646. Std of Reward: 1.509. Training.
# [INFO] Huggy. Step: 400000. Time Elapsed: 517.293 s. Mean Reward: 3.505. Std of Reward: 1.465. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy
Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1599954.onnx
# [INFO] Huggy. Step: 1650000. Time Elapsed: 2145.431 s. Mean Reward: 3.901. Std of Reward: 1.833. Training.
# [INFO] Huggy. Step: 1700000. Time Elapsed: 2207.285 s. Mean Reward: 3.759. Std of Reward: 1.798. Training.
# [INFO] Huggy. Step: 1750000. Time Elapsed: 2270.404 s. Mean Reward: 3.905. Std of Reward: 1.804. Training.
# [INFO] Huggy. Step: 1800000. Time Elapsed: 2336.643 s. Mean Reward: 3.888. Std of Reward: 1.774. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1799906.onnx
# [INFO] Huggy. Step: 1850000. Time Elapsed: 2398.304 s. Mean Reward: 3.877. Std of Reward: 1.893. Training.
# [INFO] Huggy. Step: 1900000. Time Elapsed: 2465.910 s. Mean Reward: 3.904. Std of Reward: 1.829. Training.
# [INFO] Huggy. Step: 1950000. Time Elapsed: 2529.437 s. Mean Reward: 3.872. Std of Reward: 1.835. Training.
# [INFO] Huggy. Step: 2000000. Time Elapsed: 2596.188 s. Mean Reward: 3.890. Std of Reward: 1.828. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1999939.onnx
# [INFO] Exported results/Huggy/Huggy/Huggy-2000053.onnx
# [INFO] Copied results/Huggy/Huggy/Huggy-2000053.onnx to results/Huggy/Huggy.onnx.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !mlagents-push-to-hf --run-id="HuggyTraining" --local-dir="./results/Huggy" --repo-id="MFawad/ppo-Huggy" --commit-message="Huggy"
# Out:
# [INFO] This function will create a model card and upload your HuggyTraining into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo HuggyTraining to the Hugging Face Hub
# Huggy-1399997.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
# Upload 25 LFS files:   0% 0/25 [00:00<?, ?it/s]
#
# Huggy-1199962.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
# Huggy-1199962.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
#
# Huggy-1399997.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
#
# Huggy-1599954.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
# Huggy-1199962.onnx:   1% 16.4k/2.27M [00:00<00:52, 43.3kB/s]
#
#
#
# Huggy-1399997.onnx:   1% 16.4k/2.27M [00:00<01:01, 36.5kB/s]
#
# Huggy-1199962.pt:   0% 16.4k/13.5M [00:00<06:15, 35.9kB/s]
#
#
#
#
# Huggy-1599954.onnx:   1% 16.4k/2.27M [00:00<01:04, 35.2kB/s]
#
#
# Huggy-1199962.onnx:  79% 1.80M/2.27M [00:00<00:00, 4.05MB/s]
#
#
#
# Huggy-1399997.pt:   4% 524k/13.5M [00:00<00:10, 1.18MB/s]
#
# Huggy-1399997.onnx:  24% 557k/2.27M [00:00<00:01, 1.18MB/s]
#
#
#
#
# Huggy-1599954.onnx:  25% 573k/2.27M [00:00<00:01, 1.20MB/s]
#
#
#
# Huggy-1399997.pt:   5% 737k/13.5M [00:00<00:09, 1.39MB/s]
#
#
#
#
# Huggy-1599954.onnx:  35% 803k/2.27M [00:00<00:01, 1.38MB/s]
#
# Huggy-1199962.pt:  18% 2.38M/13.5M [00:00<00:02, 3.98MB/s]
#
#
#
# Huggy-1399997.onnx:  36% 819k/2.27M [00:00<00:01, 1.19MB/s]
#
# Huggy-1199962.pt:  22% 3.01M/13.5M [00:01<00:03, 3.19MB/s]
#
#
#
# Huggy-1399997.onnx:  44% 999k/2.27M [00:01<00:01, 875kB/s]
#
# Huggy-1199962.pt:  42% 5.62M/13.5M [00:01<00:01, 6.91MB/s]
#
#
#
#
# Huggy-1599954.onnx:  51% 1.16M/2.27M [00:01<00:01, 999kB/s]
#
#
#
# Huggy-1399997.pt:  26% 3.56M/13.5M [00:01<00:02, 4.93MB/s]
#
# Huggy-1199962.pt:  51% 6.85M/13.5M [00:01<00:00, 7.68MB/s]
#
# Huggy-1199962.pt:  63% 8.54M/13.5M [00:01<00:00, 9.56MB/s]
#
#
#
# Huggy-1399997.pt:  33% 4.41M/13.5M [00:01<00:01, 4.94MB/s]
#
# Huggy-1199962.pt:  78% 10.5M/13.5M [00:01<00:00, 11.1MB/s]
#
#
#
# Huggy-1399997.pt:  40% 5.44M/13.5M [00:01<00:01, 5.15MB/s]
#
# Huggy-1199962.pt:  99% 13.3M/13.5M [00:01<00:00, 14.2MB/s]
#
#
#
# Huggy-1199962.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.22MB/s]
#
#
#
#
# Huggy-1399997.pt:  62% 8.34M/13.5M [00:01<00:00, 6.69MB/s]
# Upload 25 LFS files:   4% 1/25 [00:02<00:54,  2.26s/it]
#
#
# Huggy-1599954.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
# Huggy-1199962.pt: 100% 13.5M/13.5M [00:02<00:00, 5.64MB/s]
#
#
#
# Huggy-1599954.pt:  28% 3.72M/13.5M [00:00<00:00, 22.1MB/s]
#
#
#
# Huggy-1399997.pt:  85% 11.5M/13.5M [00:02<00:00, 6.45MB/s]
#
#
#
# Huggy-1399997.pt:  94% 12.7M/13.5M [00:02<00:00, 7.32MB/s]
#
#
# Huggy-1599954.pt:  44% 5.93M/13.5M [00:00<00:00, 12.9MB/s]
# Upload 25 LFS files:   8% 2/25 [00:02<00:28,  1.26s/it]
#
# Huggy-1799906.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
# Huggy-1599954.pt:  54% 7.36M/13.5M [00:00<00:00, 10.8MB/s]
#
#
# Huggy-1399997.onnx: 100% 2.27M/2.27M [00:03<00:00, 744kB/s]
# Huggy-1599954.onnx: 100% 2.27M/2.27M [00:03<00:00, 735kB/s]
#
#
#
# Huggy-1599954.pt:  76% 10.3M/13.5M [00:01<00:00, 6.80MB/s]
# Huggy-1799906.pt:  12% 1.65M/13.5M [00:00<00:00, 15.2MB/s]
#
#
#
#
# Huggy-199973.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
# Huggy-1399997.pt: 100% 13.5M/13.5M [00:03<00:00, 3.72MB/s]
#
#
#
# Huggy-1799906.pt:  31% 4.15M/13.5M [00:00<00:01, 6.79MB/s]
# Upload 25 LFS files:  16% 4/25 [00:04<00:18,  1.16it/s]
#
#
#
# Huggy-1799906.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.67MB/s]
#
#
#
#
# Huggy-1799906.pt:  48% 6.50M/13.5M [00:00<00:00, 7.02MB/s]
#
#
#
# Huggy-199973.pt:  61% 8.22M/13.5M [00:00<00:00, 24.6MB/s]
#
# Huggy-1599954.pt: 100% 13.5M/13.5M [00:02<00:00, 5.51MB/s]
#
# Upload 25 LFS files:  24% 6/25 [00:05<00:12,  1.58it/s]
#
#
# Huggy-1999939.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
# Huggy-1999939.pt: 100% 13.5M/13.5M [00:00<00:00, 132MB/s]
#
#
#
# Huggy-199973.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.26MB/s]
#
#
#
#
# Huggy-1999939.pt: 100% 13.5M/13.5M [00:00<00:00, 23.0MB/s]
# Huggy-1799906.pt:  92% 12.5M/13.5M [00:02<00:00, 5.12MB/s]
#
#
# Huggy.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
# Huggy-1999939.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.45MB/s]
#
#
# Huggy-2000053.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
# Huggy-2000053.pt:  46% 6.24M/13.5M [00:00<00:00, 43.3MB/s]
#
#
#
#
# Huggy-399853.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
# Huggy-1799906.pt: 100% 13.5M/13.5M [00:03<00:00, 4.23MB/s]
# Huggy-199973.pt: 100% 13.5M/13.5M [00:02<00:00, 5.17MB/s]
#
# Huggy-399853.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
# Huggy-599985.onnx: 100% 2.27M/2.27M [00:00<00:00, 5.86MB/s]
# Huggy.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.27MB/s]
# Huggy-399853.pt: 100% 13.5M/13.5M [00:00<00:00, 26.3MB/s]
#
# Huggy-599985.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
# Huggy-399853.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.40MB/s]
# Huggy-2000053.pt: 100% 13.5M/13.5M [00:01<00:00, 6.86MB/s]
#
#
# Huggy-599985.pt:  59% 7.95M/13.5M [00:00<00:00, 28.3MB/s]
#
# Huggy-799946.pt:  45% 6.11M/13.5M [00:00<00:00, 37.0MB/s]
#
#
#
# Huggy-999955.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
# Upload 25 LFS files:  56% 14/25 [00:08<00:04,  2.33it/s]
#
#
#
#
# Huggy-999955.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
# Huggy-799946.pt:  73% 9.83M/13.5M [00:00<00:00, 26.8MB/s]
#
#
#
#
# Huggy-999955.pt:  32% 4.26M/13.5M [00:00<00:00, 30.4MB/s]
#
#
#
#
# Huggy-599985.pt: 100% 13.5M/13.5M [00:01<00:00, 12.5MB/s]
#
#
#
#
#
# Huggy-999955.pt:  79% 10.7M/13.5M [00:00<00:00, 10.6MB/s]
# checkpoint.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
# Huggy-799946.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.34MB/s]
# Huggy-999955.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.57MB/s]
# checkpoint.pt: 100% 13.5M/13.5M [00:00<00:00, 22.7MB/s]
# events.out.tfevents.1702822384.44639419006c.5085.0:   0% 0.00/361k [00:00<?, ?B/s]
# Upload 25 LFS files:  76% 19/25 [00:09<00:02,  2.72it/s]
#
#
# Huggy.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
#
#
# Huggy-799946.pt: 100% 13.5M/13.5M [00:02<00:00, 5.56MB/s]
# Huggy.onnx: 100% 2.27M/2.27M [00:00<00:00, 3.89MB/s]
#
# events.out.tfevents.1702822384.44639419006c.5085.0: 100% 361k/361k [00:01<00:00, 336kB/s]
# Huggy-999955.pt: 100% 13.5M/13.5M [00:03<00:00, 4.26MB/s]
#
# Upload 25 LFS files: 100% 25/25 [00:11<00:00,  2.11it/s]
# [INFO] Your model is pushed to the hub. You can view your model here: https://huggingface.co/MFawad/ppo-Huggy
